# %% [markdown]
# # The Sparks Foundation Task-3
# Perform ‘Exploratory Data Analysis’ on dataset ‘SampleSuperstore’ and try to find out the weak areas where you can work to make more profit.
#
#
# Author - Aryan Tiwari

# %% [markdown]
# # IMPORTING THE LIBRARIES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # IMPORTING THE DATASET

# %%
data=pd.read_csv("SampleSuperstore.csv")

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
data.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480

# %%
data.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.shape # 9994 rows and 13 columns are there
# Out:
# (9994, 13)

# %%
data.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
data.value_counts()
# Out:
# Ship Mode       Segment      Country        City           State       Postal Code  Region   Category         Sub-Category  Sales    Quantity  Discount  Profit
# Standard Class  Consumer     United States  Salem          Oregon      97301        West     Office Supplies  Paper         10.368   2         0.2        3.6288      2
# Second Class    Corporate    United States  Chicago        Illinois    60653        Central  Office Supplies  Binders       3.564    3         0.8       -6.2370      2
# Standard Class  Consumer     United States  San Francisco  California  94122        West     Office Supplies  Paper         12.840   3         0.0        5.7780      2
#                                             Los Angeles    California  90036        West     Office Supplies  Paper         19.440   3         0.0        9.3312      2
# Same Day        Home Office  United States  San Francisco  California  94122        West     Office Supplies  Labels        41.400   4         0.0        19.8720     2
#                                                                                                                                                                      ..
# Second Class    Corporate    United States  Las Vegas      Nevada      89115        West     Office Supplies  Paper         97.880   2         0.0        48.9400     1
#                                             Little Rock    Arkansas    72209        South    Office Supplies  Envelopes     182.940  3         0.0        85.9818     1
#                                                                                                               Paper         44.960   2         0.0        20.6816     1
#                                                                                                               Storage       62.040   4         0.0        17.3712     1
# Standard Class  Home Office  United States  Yuma           Arizona     85364        West     Technology       Machines      599.985  5         0.7       -479.9880    1
# Length: 9977, dtype: int64

# %% [markdown]
# # Cleaning the dataset

# %%
dataset = data.drop(['Segment','Country','State','Region'], axis = 1)

# %%
dataset.shape
# Out:
# (9994, 9)

# %%
data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
duplicate=dataset.duplicated()
print(duplicate.sum())
dataset[duplicate]
# Out:
# 31
#            Ship Mode           City  Postal Code         Category  \
# 950   Standard Class   Philadelphia        19120  Office Supplies
# 2198  Standard Class   Philadelphia        19120  Office Supplies
# 2290  Standard Class       Columbus        31907       Technology
# 2729  Standard Class        Seattle        98105  Office Supplies
# 2979  Standard Class   Philadelphia        19134  Office Supplies
# 3406  Standard Class       Columbus        43229        Furniture
# 3670  Standard Class          Salem        97301  Office Supplies
# 4117  Standard Class    Los Angeles        90036  Office Supplies
# 4553  Standard Class  San Francisco        94122  Office Supplies
# 5109  Standard Class   Philadelphia        19134  Office Supplies
# 5374  Standard Class        Houston        77041  Office Supplies
# 5905        Same Day  San Francisco        94122  Office Supplies
# 6017  Standard Class    Los Angeles        90049  Office Supplies
# 6146  Standard Class  San Francisco        94122  Office Supplies
# 6192  Standard Class        Houston        77095  Office Supplies
# 6334  Standard Class  New York City        10011  Office Supplies
# 6357  Standard Class        Seattle        98103  Office Supplies
# 7608  Standard Class  San Francisco        94122  Office Supplies
# 7735  Standard Class        Seattle        98105  Office Supplies
# 7742  Standard Class    Los Angeles        90036  Office Supplies
# 7759  Standard Class        Houston        77041  Office Supplies
# 8032     First Class        Houston        77041  Office Supplies
# 8064     First Class      Rochester        14609  Office Supplies
# 8095    Second Class        Seattle        98115  Office Supplies
# 8287  Standard Class          Miami        33180  Office Supplies
# 8513  Standard Class        Orlando        32839  Office Supplies
# 8897  Standard Class    Los Angeles        90004  Office Supplies
# 9244  Standard Class  San Francisco        94122  Office Supplies
# 9262  Standard Class        Detroit        48227        Furniture
# 9363  Standard Class        Seattle        98105        Furniture
# 9477    Second Class        Chicago        60653  Office Supplies
#
#      Sub-Category    Sales  Quantity  Discount   Profit
# 950         Paper   15.552         3       0.2   5.4432
# 2198        Paper   15.552         3       0.2   5.4432
# 2290       Phones  287.970         3       0.0  77.7519
# 2729          Art    6.630         3       0.0   1.7901
# 2979        Paper   20.736         4       0.2   7.2576
# 3406       Chairs  281.372         2       0.3 -12.0588
# 3670        Paper   10.368         2       0.2   3.6288
# 4117        Paper   19.440         3       0.0   9.3312
# 4553        Paper   12.840         3       0.0   5.7780
# 5109    Envelopes   52.512         6       0.2  19.6920
# 5374        Paper   10.368         2       0.2   3.6288
# 5905       Labels   41.400         4       0.0  19.8720
# 6017        Paper   19.440         3       0.0   9.3312
# 6146          Art   11.760         4       0.0   3.1752
# 6192        Paper   25.920         5       0.2   9.0720
# 6334        Paper   49.120         4       0.0  23.0864
# 6357        Paper   25.920         4       0.0  12.4416
# 7608        Paper   25.920         4       0.0  12.4416
# 7735        Paper   19.440         3       0.0   9.3312
# 7742        Paper   25.920         4       0.0  12.4416
# 7759        Paper   15.552         3       0.2   5.4432
# 8032        Paper   47.952         3       0.2  16.1838
# 8064        Paper   12.960         2       0.0   6.2208
# 8095        Paper   12.960         2       0.0   6.2208
# 8287          Art   47.960         5       0.2   4.1965
# 8513        Paper   20.736         4       0.2   7.2576
# 8897        Paper   37.520         4       0.0  18.0096
# 9244          Art    5.560         2       0.0   2.2240
# 9262       Chairs  389.970         3       0.0  35.0973
# 9363  Furnishings   22.140         3       0.0   6.4206
# 9477      Binders    3.564         3       0.8  -6.2370

# %% [markdown]
# # DATA VISUALIZATION

# %%
corelation=dataset.corr()
print(corelation)
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(corelation, xticklabels=corelation.columns, yticklabels=corelation.columns, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Here we can see discount and profit are highly negatively corelated. Values closer to zero means there is no linear trend between the two variables. The close to 1 the correlation is the more positively correlated they are; that is as one increases so does the other and the closer to 1 the stronger this relationship is. A correlation closer to -1 is similar, but instead of both increasing one variable will decrease as the other increases
#
# 1) Here we can see discount and profit are highly negatively corelated
#
# 2) Sales and Profits are Moderately Correlated
#
# 3) Quantity and Profit are Moderately Correlated

# %%
sns.boxplot(x=data['Discount'])
# Out:
# <AxesSubplot:xlabel='Discount'>

# %%
sns.boxplot(x=data['Profit'])
# Out:
# <AxesSubplot:xlabel='Profit'>

# %%
sns.boxplot(x=data['Sales'])
# Out:
# <AxesSubplot:xlabel='Sales'>

# %%
sns.displot(data,x='Quantity',hue='Sub-Category',kind='hist',fill='tree',palette='colorblind',color='g')

# %% [markdown]
# In the above sub-category section, with respect to profit:
#
# 1) Tablets are expereincing loss
#
# 2) Supplies produces the least amout of profit
#
# 3) PAPER produces maximum profit

# %%
sns.barplot(x=data['Sales'])
# Out:
# <AxesSubplot:xlabel='Sales'>

# %%
sns.displot(data,x='Quantity',hue='Sub-Category',kind='kde',fill='tree',palette='colorblind',color='g')

# %%
sns.displot(data,x='Discount',hue='Sub-Category',kind='kde',fill='tree',palette='colorblind',color='g')

# %% [markdown]
# In the above sub-category section, with respect to profit:
#
# 1) Tablets are expereincing loss
#
# 2) Supplies produces the least amout of profit
#
# 3) PAPER produces maximum profit

# %%
sns.lineplot(data=data)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x=data['Sales'],y=data['Discount'])
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Discount'>

# %%
sns.jointplot(x=data['Quantity'],y=data['Discount'])

# %% [markdown]
# When we compare the Quantity with respect to discounts, all the discounts above 20% is facing a major loss

# %%
plt.figure(figsize=(12,6))
sns.lineplot(data=data)
sns.set_style("dark")

# %% [markdown]
# When the data of different states is analysed, we can conclude that California recieves maximum amount of profit with maximum sales when compared to the other states.

# %%
fig,ax=plt.subplots()
ax.plot(data['Discount'],data['Sales'],marker='v',linestyle='--')
plt.xlabel("Discount")
plt.ylabel("Sales")
plt.show()

# %%
sns.relplot(x='Sales', y='Profit', hue='Sub-Category', data=dataset)

# %% [markdown]
# In the Category Section:
#
# 1) Almost 60% of products belong to Office supplies
#
# 2) Almost 18% of product belong to Technology which is the minimum

# %% [markdown]
# Conclusions when the ship mode data is analysed:
#
# 1) Maximum number of shipments belong to tha standard class
#
# 2) whereas, very less number of shipments are done on the same day (10%)
